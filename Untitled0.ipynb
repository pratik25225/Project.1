# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/data_usage.csv.txt")

# %%
df
# Out:
#   Time_Start       App_Name         Category  Duration_Min  Usage_MB
# 0      07:30        Spotify            Audio            30        60
# 1      08:15      Instagram           Social            30       350
# 2      09:00           Zoom       Work_Video            60      1200
# 3      10:00          Slack     Productivity           120       150
# 4      12:30         TikTok     Social_Video            30       450
# 5      14:00  Google_Chrome     Web_Browsing            90       200
# 6      17:00        YouTube  Video_Streaming            60      1800
# 7      19:00   Call_of_Duty           Gaming            90       250
# 8      20:30        Netflix         Video_4K           120      6000
# 9      22:30       WhatsApp        Messaging            30        20

# %%
df["Consumption Rate"]=df["Usage_MB"]/df["Duration_Min"]
df["data_usage"]=df["Duration_Min"]*df["Consumption Rate"]

# %%
plt.figure()
plt.plot(df.index, df["data_usage"])
plt.xlabel('Entry Index')
plt.ylabel('Data Usage (MB/Min)')
plt.title('Data Usage per Minute')
plt.show()

# %%
peak_index = df['Usage_MB'].idxmax()
peak_hour = df.loc[peak_index, 'Time_Start']
peak_app = df.loc[peak_index, 'App_Name']
correlation = df['Duration_Min'].corr(df['Usage_MB'])

# %%
print(f"Peak Consumption Hour: {peak_hour} (App: {peak_app})")
print(f"Correlation between Duration and Usage: {correlation:.4f}")
# Out:
# Peak Consumption Hour: 20:30 (App: Netflix)
# Correlation between Duration and Usage: 0.4827
